# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram04r/FMML.LABS-/blob/main/FMML_2024_Module_04_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Foundations of Modern Machine Learning, IIIT Hyderabad
#
# Project: Perceptron and Gradient Descent
#
# Note: Please write the code for the following tasks in separate code cells.

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# ### Example 1 - A simple cost function
#
# #### $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ### Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ### Gradient Descent

# %%
import numpy as np

# Define the function and its derivative
def f(x):
    return (x - 3)**2 + 4

def df(x):
    return 2 * (x - 3)

# Gradient descent parameters
learning_rate = 0.1
num_iterations = 100
initial_x = 0  # Starting point

# Gradient descent loop
x = initial_x
for i in range(num_iterations):
    grad = df(x)
    x = x - learning_rate * grad
    if i % 10 == 0:  # Print progress every 10 iterations
        print(f"Iteration {i}: x = {x}, f(x) = {f(x)}")

print(f"Minimum found at x = {x}, f(x) = {f(x)}")
# Out:
# Iteration 0: x = 0.6000000000000001, f(x) = 9.76
# Iteration 10: x = 2.74230196224, f(x) = 4.066408278665355
# Iteration 20: x = 2.9723298838894356, f(x) = 4.000765635325572
# Iteration 30: x = 2.997028943905715, f(x) = 4.000008827174315
# Iteration 40: x = 2.9996809852810116, f(x) = 4.000000101770391
# Iteration 50: x = 2.999965746055375, f(x) = 4.0000000011733325
# Iteration 60: x = 2.9999963220107015, f(x) = 4.000000000013528
# Iteration 70: x = 2.999999605078906, f(x) = 4.000000000000156
# Iteration 80: x = 2.99999995759567, f(x) = 4.000000000000002
# Iteration 90: x = 2.9999999954468697, f(x) = 4.0
# Minimum found at x = 2.9999999993888893, f(x) = 4.0

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# ### Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# #### $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
import numpy as np

def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=1000):
    new_x = initial_guess
    x_list = [new_x]
    deriv_list = [derivative_func(new_x)]
    for _ in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        x_list.append(new_x)
        deriv_list.append(derivative_func(new_x))
        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break
    return new_x, x_list, deriv_list

# Example derivative function for f(x) = (x-3)^2 + 4 which is f'(x) = 2*(x-3)
def dg(x):
    return 2 * (x - 3)

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)

# Print the results
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 2.9761844522178746
# Number of steps: 115

# %%
import numpy as np

def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=1000):
    new_x = initial_guess
    x_list = [new_x]
    deriv_list = [derivative_func(new_x)]
    for _ in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        x_list.append(new_x)
        deriv_list.append(derivative_func(new_x))
        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break
    return new_x, x_list, deriv_list

# Example derivative function for f(x) = (x-3)^2 + 4 which is f'(x) = 2*(x-3)
def dg(x):
    return 2 * (x - 3)

# Running gradient descent
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5,
                                                 multiplier=0.01, precision=0.0001)

print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 2.99517198378402
# Number of steps: 327

# %%
import numpy as np

def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    x_list = [new_x]
    deriv_list = [derivative_func(new_x)]
    for _ in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        x_list.append(new_x)
        deriv_list.append(derivative_func(new_x))
        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break
    return new_x, x_list, deriv_list

# Example derivative function for f(x) = (x-3)^2 + 4 which is f'(x) = 2*(x-3)
def dg(x):
    return 2 * (x - 3)

# Running gradient descent with the specified initial guess
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 2.9951726819279263
# Number of steps: 321

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    x_list = [new_x]
    deriv_list = [derivative_func(new_x)]
    for _ in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        x_list.append(new_x)
        deriv_list.append(derivative_func(new_x))
        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break
    return new_x, x_list, deriv_list

# %% [markdown]
# ### Example 3 - Divergence and Overflow
#
# #### $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %% [markdown]
# #### Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    x_list = [new_x]
    deriv_list = [derivative_func(new_x)]
    for _ in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        x_list.append(new_x)
        deriv_list.append(derivative_func(new_x))
        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break
    return new_x, x_list, deriv_list

# Example derivative function for f(x) = (x-3)^2 + 4 which is f'(x) = 2*(x-3)
def dg(x):
    return 2 * (x - 3)

# Define the original function
def g(x):
    return (x - 3)**2 + 4

# Generate x values for plotting
x_2 = np.linspace(-2, 2, 400)

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                                 multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side
plt.figure(figsize=[15, 5])

# 1st Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2nd Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is:', len(list_x))
# Out:
# Number of steps is: 152

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(derivative_func, initial_guess, multiplier, precision=0.0001, max_iter=1000):
    new_x = initial_guess
    x_list = [new_x]
    deriv_list = [derivative_func(new_x)]
    for _ in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient
        x_list.append(new_x)
        deriv_list.append(derivative_func(new_x))
        step_size = abs(new_x - previous_x)
        if step_size < precision:
            break
    return new_x, x_list, deriv_list

# Example derivative function for f(x) = (x-3)^2 + 4 which is f'(x) = 2*(x-3)
def dg(x):
    return 2 * (x - 3)

# Define the original function
def g(x):
    return (x - 3)**2 + 4

# Generate x values for plotting
x_2 = np.linspace(-2, 8, 400)

# TASK-5: Run gradient descent 3 times with different learning rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# TASK-6: Experiment with an insane learning rate
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting results
plt.figure(figsize=[20, 10])

# Plot low_gamma
plt.subplot(2, 2, 1)
plt.xlim(-2, 8)
plt.ylim(0, 20)
plt.title('Gradient Descent with low_gamma (0.0005)', fontsize=15)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.plot(x_2, g(x_2), color='blue', linewidth=2, alpha=0.8)
plt.scatter(low_gamma[1], g(np.array(low_gamma[1])), color='red', s=50, alpha=0.6)

# Plot mid_gamma
plt.subplot(2, 2, 2)
plt.xlim(-2, 8)
plt.ylim(0, 20)
plt.title('Gradient Descent with mid_gamma (0.001)', fontsize=15)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.plot(x_2, g(x_2), color='blue', linewidth=2, alpha=0.8)
plt.scatter(mid_gamma[1], g(np.array(mid_gamma[1])), color='red', s=50, alpha=0.6)

# Plot high_gamma
plt.subplot(2, 2, 3)
plt.xlim(-2, 8)
plt.ylim(0, 20)
plt.title('Gradient Descent with high_gamma (0.002)', fontsize=15)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.plot(x_2, g(x_2), color='blue', linewidth=2, alpha=0.8)
plt.scatter(high_gamma[1], g(np.array(high_gamma[1])), color='red', s=50, alpha=0.6)

# Plot insane_gamma
plt.subplot(2, 2, 4)
plt.xlim(-2, 8)
plt.ylim(0, 20)
plt.title('Gradient Descent with insane_gamma (0.25)', fontsize=15)
plt.xlabel('X', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.plot(x_2, g(x_2), color='blue', linewidth=2, alpha=0.8)
plt.scatter(insane_gamma[1], g(np.array(insane_gamma[1])), color='red', s=50, alpha=0.6)

plt.show()

# %%
## TASK-7 : Plot reduction in cost for each iteration

# %% [markdown]
# ### Example 4 - Data Viz with 3D Charts
#
# #### Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define the function f(x, y)
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate x and y values
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)

# Calculate z values
z_4 = f(x_4, y_4)

# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plotting the surface
ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.8)

plt.show()

# %% [markdown]
# ### TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
#
# #### Partial Derivatives & Symbolic Computation
#
# #### $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# #### $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
from sympy import symbols, diff

# Define the symbols
a, b = symbols('a b')

# Define the function
def f(a, b):
    return (a - 3)**2 + (b - 2)**2 + 4

# Print the cost function
print('Our cost function f(a, b) is: ', f(a, b))

# Print the partial derivative with respect to b
print('Partial derivative wrt y is: ', diff(f(a, b), b))

# Evaluate the function at a=1.8 and b=1.0
print('Value of f(a, b) at a=1.8, b=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0}))

# Print the value of the partial derivative wrt a
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function f(a, b) is:  (a - 3)**2 + (b - 2)**2 + 4
# Partial derivative wrt y is:  2*b - 4
# Value of f(a, b) at a=1.8, b=1.0 is:  6.44000000000000
# Value of partial derivative wrt x:  -2.40000000000000

# %% [markdown]
# #### Batch Gradient Descent with SymPy
#
# *   List item
# *   List item

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [-1.77635683940025e-15 -8.88178419700125e-16]
# Minimum occurs at x value of:  3.00000000000000
# Minimum occurs at y value of:  2.00000000000000
# The cost is:  4.00000000000000

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
import numpy as np

# Define the function and its partial derivatives
def f(x, y):
    return (x - 3)**2 + (y - 2)**2 + 4

def fpx(x, y):
    return 2 * (x - 3)

def fpy(x, y):
    return 2 * (y - 2)

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Values in gradient array: [-1.77635684e-15 -8.88178420e-16]
# Minimum occurs at x value of: 2.999999999999999
# Minimum occurs at y value of: 1.9999999999999996
# The cost is: 4.0

# %% [markdown]
# ```
# #### This is formatted as code
# ```
#
# ### Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [-1.77635684e-15 -8.88178420e-16]
# Minimum occurs at x value of:  2.999999999999999
# Minimum occurs at y value of:  1.9999999999999996
# The cost is:  4.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define the function
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate x and y values
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)

# Calculate z values
z_4 = f(x_4, y_4)

# Example values array for scatter plot
values_array = np.array([[1, 1], [2, 2], [3, 3]])

# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plotting the surface
ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.8)

# Scatter plot of specific points
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# #### For Reference, practice and play with the code below
#
# ### Example 5 - Working with data & a real cost function
#
# #### Mean Squared Error: a cost function for regression problems
#
# #### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# #### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# #### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# #### 3D Plot for the MSE Cost Function
#
# #### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# #### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# <ipython-input-118-050b7bf9b7b1>:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plot_cost[i][j] = mse(y_5, y_hat)
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define the cost function (MSE) for example purposes
def mse(theta_0, theta_1, X, y):
    predictions = theta_0 + theta_1 * X
    errors = predictions - y
    return np.mean(errors**2)

# Generate data for plotting
theta_0 = np.linspace(-10, 10, 100)
theta_1 = np.linspace(-1, 4, 100)
theta_0, theta_1 = np.meshgrid(theta_0, theta_1)

# Example data points
X = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 1.3, 3.75, 2.25])

# Calculate the cost for each pair of (theta_0, theta_1)
plot_cost = np.array([mse(t0, t1, X, y) for t0, t1 in zip(np.ravel(theta_0), np.ravel(theta_1))])
plot_cost = plot_cost.reshape(theta_0.shape)

# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

# Plotting the surface
ax.plot_surface(theta_0, theta_1, plot_cost, cmap=cm.hot)

plt.show()

# %%
import numpy as np

# Example definitions of plot_t0, plot_t1, and plot_cost
# Generate data for plotting
theta_0 = np.linspace(-10, 10, 100)
theta_1 = np.linspace(-1, 4, 100)
plot_t0, plot_t1 = np.meshgrid(theta_0, theta_1)

# Example data points
X = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 1.3, 3.75, 2.25])

# Define the cost function (MSE)
def mse(theta_0, theta_1, X, y):
    predictions = theta_0 + theta_1 * X
    errors = predictions - y
    return np.mean(errors**2)

# Calculate the cost for each pair of (theta_0, theta_1)
plot_cost = np.array([mse(t0, t1, X, y) for t0, t1 in zip(np.ravel]
print('Min MSE for Theta 0:', min_theta_0)
print('Min MSE for Theta 1:', min_theta_1)
# Out:
#   File "<ipython-input-120-4f9ca0db5709>", line 20
#     plot_cost = np.array([mse(t0, t1, X, y) for t0, t1 in zip(np.ravel]
#                                                                       ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %% [markdown]
# #### Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# #### $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# #### $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# #### MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
